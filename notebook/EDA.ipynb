# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/Users/sumitchougale/Downloads/digital_marketing_campaign_dataset.csv')

# %%
df.head()
# Out:
#    CustomerID  Age  Gender  Income CampaignChannel CampaignType      AdSpend  \
# 0        8000   56  Female  136912    Social Media    Awareness  6497.870068
# 1        8001   69    Male   41760           Email    Retention  3898.668606
# 2        8002   46  Female   88456             PPC    Awareness  1546.429596
# 3        8003   32  Female   44085             PPC   Conversion   539.525936
# 4        8004   60  Female   83964             PPC   Conversion  1678.043573
#
#    ClickThroughRate  ConversionRate  WebsiteVisits  PagesPerVisit  TimeOnSite  \
# 0          0.043919        0.088031              0       2.399017    7.396803
# 1          0.155725        0.182725             42       2.917138    5.352549
# 2          0.277490        0.076423              2       8.223619   13.794901
# 3          0.137611        0.088004             47       4.540939   14.688363
# 4          0.252851        0.109940              0       2.046847   13.993370
#
# ...

# %%
df=df.drop(columns=['CustomerID','AdvertisingPlatform','AdvertisingTool'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                8000 non-null   int64
#  1   Gender             8000 non-null   object
#  2   Income             8000 non-null   int64
#  3   CampaignChannel    8000 non-null   object
#  4   CampaignType       8000 non-null   object
#  5   AdSpend            8000 non-null   float64
#  6   ClickThroughRate   8000 non-null   float64
#  7   ConversionRate     8000 non-null   float64
#  8   WebsiteVisits      8000 non-null   int64
#  9   PagesPerVisit      8000 non-null   float64
#  10  TimeOnSite         8000 non-null   float64
#  11  SocialShares       8000 non-null   int64
#  12  EmailOpens         8000 non-null   int64
#  13  EmailClicks        8000 non-null   int64
#  14  PreviousPurchases  8000 non-null   int64
#  15  LoyaltyPoints      8000 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age         Income      AdSpend  ClickThroughRate  \
# count  8000.000000    8000.000000  8000.000000       8000.000000
# mean     43.625500   84664.196750  5000.944830          0.154829
# std      14.902785   37580.387945  2838.038153          0.084007
# min      18.000000   20014.000000   100.054813          0.010005
# 25%      31.000000   51744.500000  2523.221165          0.082635
# 50%      43.000000   84926.500000  5013.440044          0.154505
# 75%      56.000000  116815.750000  7407.989369          0.228207
# max      69.000000  149986.000000  9997.914781          0.299968
#
#        ConversionRate  WebsiteVisits  PagesPerVisit   TimeOnSite  \
# count     8000.000000    8000.000000    8000.000000  8000.000000
# mean         0.104389      24.751625       5.549299     7.727718
# std          0.054878      14.312269       2.607358     4.228218
# min          0.010018       0.000000       1.000428     0.501669
# ...

# %%
df.isna().sum()
# Out:
# Age                  0
# Gender               0
# Income               0
# CampaignChannel      0
# CampaignType         0
# AdSpend              0
# ClickThroughRate     0
# ConversionRate       0
# WebsiteVisits        0
# PagesPerVisit        0
# TimeOnSite           0
# SocialShares         0
# EmailOpens           0
# EmailClicks          0
# PreviousPurchases    0
# LoyaltyPoints        0
# Conversion           0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt


ax = sns.countplot(data=df, x='Conversion')


for p in ax.patches:

    height = p.get_height()
    #
    ax.text(p.get_x() + p.get_width() / 2., height, f'{int(height)}', 
            ha='center', va='bottom')

plt.title('Distribution of Conversion')
plt.show()

# %%
sns.violinplot(data=df,x='Conversion',y='AdSpend')
# Out:
# <Axes: xlabel='Conversion', ylabel='AdSpend'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.boxplot(data=df,y='AdSpend',x='Gender',hue='Conversion')
plt.legend(loc=(1.1,0.5))

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Income', 'CampaignChannel', 'CampaignType', 'AdSpend',
#        'ClickThroughRate', 'ConversionRate', 'WebsiteVisits', 'PagesPerVisit',
#        'TimeOnSite', 'SocialShares', 'EmailOpens', 'EmailClicks',
#        'PreviousPurchases', 'LoyaltyPoints', 'Conversion'],
#       dtype='object')

# %%
corr_df  = pd.get_dummies(df[['Age', 'Gender', 'Income', 'CampaignChannel', 'CampaignType', 'AdSpend',
       'ClickThroughRate', 'ConversionRate', 'WebsiteVisits', 'PagesPerVisit',
       'TimeOnSite', 'SocialShares', 'EmailOpens', 'EmailClicks',
       'PreviousPurchases', 'LoyaltyPoints', 'Conversion']]).corr()

# %%
corr_df['Conversion'].sort_values().iloc[1:-1]
# Out:
# CampaignType_Awareness         -0.036470
# CampaignType_Retention         -0.031471
# CampaignChannel_Social Media   -0.012015
# SocialShares                   -0.011449
# CampaignChannel_Email          -0.009318
# Gender_Female                  -0.001075
# CampaignChannel_SEO             0.000409
# Gender_Male                     0.001075
# Age                             0.001606
# CampaignChannel_PPC             0.009748
# CampaignChannel_Referral        0.010449
# Income                          0.013974
# WebsiteVisits                   0.079339
# ConversionRate                  0.093185
# LoyaltyPoints                   0.095004
# CampaignType_Conversion         0.102696
# PagesPerVisit                   0.102840
# PreviousPurchases               0.111781
# ClickThroughRate                0.120012
# AdSpend                         0.124672
# EmailOpens                      0.124884
# EmailClicks                     0.129521
# TimeOnSite                      0.129609
# ...

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.barplot(x=corr_df['Conversion'].sort_values().iloc[1:-1].index,y=corr_df['Conversion'].sort_values().iloc[1:-1].values)
plt.title("Feature Correlation to Conversion")
plt.xticks(rotation=90);

# %%
numeric_columns = df.select_dtypes(include=[int, float]).columns
numeric_columns = [col for col in numeric_columns if col != 'Conversion']

# %%
numeric_columns
# Out:
# ['Age',
#  'Income',
#  'AdSpend',
#  'ClickThroughRate',
#  'ConversionRate',
#  'WebsiteVisits',
#  'PagesPerVisit',
#  'TimeOnSite',
#  'SocialShares',
#  'EmailOpens',
#  'EmailClicks',
#  'PreviousPurchases',
#  'LoyaltyPoints']

# %%
for column in numeric_columns:
    plt.figure(figsize=(8, 4))
    plt.boxplot(df[column].dropna())  # Drop NA values if any
    plt.title(f'Box Plot for {column}')
    plt.ylabel(column)
    plt.show()

# %%
outliers_dict = {}

for column in numeric_columns:
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    print(f"Column: {column}")
    print(f"Q1: {Q1}, Q3: {Q3}, IQR: {IQR}")
    print(f"Lower Bound: {lower_bound}, Upper Bound: {upper_bound}")

    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    
    print(f"Number of outliers in '{column}': {outliers.shape[0]}")

    if not outliers.empty:
        outliers_dict[column] = outliers

# Print outliers if any
if outliers_dict:
    for column, outliers in outliers_dict.items():
        print(f"\nColumn: {column}")
        print(outliers)
else:
    print("No outliers detected in the numeric columns.")
# Out:
# Column: Age
# Q1: 31.0, Q3: 56.0, IQR: 25.0
# Lower Bound: -6.5, Upper Bound: 93.5
# Number of outliers in 'Age': 0
# Column: Income
# Q1: 51744.5, Q3: 116815.75, IQR: 65071.25
# Lower Bound: -45862.375, Upper Bound: 214422.625
# Number of outliers in 'Income': 0
# Column: AdSpend
# Q1: 2523.2211648076745, Q3: 7407.989369393643, IQR: 4884.768204585968
# Lower Bound: -4803.9311420712775, Upper Bound: 14735.141676272595
# Number of outliers in 'AdSpend': 0
# Column: ClickThroughRate
# Q1: 0.08263496472274802, Q3: 0.22820696121014994, IQR: 0.14557199648740193
# Lower Bound: -0.1357230300083549, Upper Bound: 0.44656495594125284
# Number of outliers in 'ClickThroughRate': 0
# Column: ConversionRate
# Q1: 0.05640951423432732, Q3: 0.15207690338364352, IQR: 0.09566738914931619
# Lower Bound: -0.08709156948964697, Upper Bound: 0.29557798710761785
# Number of outliers in 'ConversionRate': 0
# Column: WebsiteVisits
# Q1: 13.0, Q3: 37.0, IQR: 24.0
# Lower Bound: -23.0, Upper Bound: 73.0
# ...

# %%
# Histograms for numerical features
df.hist(bins=20, figsize=(20, 15))
plt.show()

# Box plots for numerical features
sns.boxplot(data=df[['Age', 'Income', 'AdSpend']])
plt.show()

# Bar plots for categorical features
for col in ['Gender', 'CampaignChannel', 'CampaignType', 'AdvertisingPlatform']:
    sns.countplot(x=col, data=df)
    plt.show()

# %%
# Scatter plot
sns.scatterplot(x='AdSpend', y='ConversionRate', data=df)
plt.show()

# Correlation matrix
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# Box plot for categorical vs numerical
sns.boxplot(x='CampaignChannel', y='AdSpend', data=df)
plt.show()

# Heatmap for categorical-categorical
crosstab = pd.crosstab(df['CampaignChannel'], df['CampaignType'])
sns.heatmap(crosstab, annot=True, cmap='Blues')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 6
#       3 plt.show()
#       5 # Correlation matrix
# ----> 6 corr_matrix = df.corr()
#       7 sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
#       8 plt.show()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...
